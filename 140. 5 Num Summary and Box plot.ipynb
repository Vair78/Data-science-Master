# %% [markdown]
# # 140. 5 Num Summary and Box plot.ipynb
# [To Find Outlier ]
#
# df.describe().loc[['min', '25%', '50%', '75%', 'max']]

# %% [markdown]
# A five number summary is a way to summarize a dataset using the following five values:
#
# 1. The minimum
# 2. The first quartile
# 3. The median
# 4. The third quartile
# 5. The maximum
#
# The five number summary is useful because it provides a concise summary of the distribution of the data in the following ways:
#
# * It tells us where the middle value is located, using the median.
# * It tells us how spread out the data is, using the first and third quartiles.
# * It tells us the range of the data, using the minimum and the maximum.
#
# The easiest way to calculate a five number summary for variables in a pandas DataFrame is to use the describe() function as follows:

# %% [markdown]
# x = {1,2,2,2,3,3,4,5,5,5,6,6,6,6,7,8,8,9,29} n=19
#
# - [Lower fence <-> Higher Fence]
# - IQR = Inter Quartile Range
#
# - Lower Fence = Q1 -1.5(IQR)
# - higher Fence = Q3 +1.5(IQR)
#
# - Q1 = 25 percentile = 25/100*(19+1) = 25/100*20 = 5th Index
# - Q1 = 3 (5th Index)
#
#
# - Q3 = 75 pecentile = 75/100*(19+1) = 75/100* 20 = 15 th index
# -   Q3 = 7 (15th Index from X)
#
# -  IQR = Q3 - Q1 = 7-3 = 4
#
# -  lower Fence = Q1 - 1.5(IQR)  = 3-1.5 (4) = 3-6 = -3
#
# -   Higher Fence = Q3 + 1.5(IQR) = 7 + 1.5 (4) = 7+6 = 13
#
# - The Outlier for this [-3 , 13 ]
#
# - to Find outlier = Greater than 13 then only 29  and -3 ther is no below -3 so only 29 is outlier

# %% [markdown]
# ## 5 Number Summary using above example
# - Mininum = 1  # From X values
# - Q1 = 3   # Anwser of Q1
# - Median = 5   # median of the value
# - Q3 = 7
# -  Maximum =9      # exclusing outlier what is max number in values(X)

# %% [markdown]
# # Question 4: Find the 5 number summary for the given data 10, 20, 5, 15, 25, 30, 8
#
# Solution:
#
# Step-1 Sort the given data in ascending order.
# 5, 8, 10, 15, 20, 25, 30
#
# Step-2
# As the given data is same as the above examples we can get minimum value, median and maximum from there.
#
# So, Minimum = 5
#
# Maximum = 30
#
# Median = 15
#
# Now find 1st and 3rd quartile either by using formula or by picking center value. Both gives same result.
#
# For Quartile-1 Formula is ((n + 1)/4)th term where n is the count of numbers in the dataset.
#
# n = 7 because there are 7 numbers in the data.
#
# Quartile-1 = ((7 + 1)4)th term
#
# = (8/4)th term
#
# = 2nd term
#
# 2nd term is 8 So, Quartile-1 = 8
#
# In the same way find the quartile-3 using the formula (3(n + 1)/4)th term.
#
# Quartile 3 = (3(7 + 1)/4)th term
#
# = (3(8)/4)th term
#
# = (24/4)th term
#
#  = 6th term
#
# 6th term is 25 so  Quartile-3 = 25
#
#  # Question 5: Find out the 5 number summary for the data 1, 10, 5, 15, 2, 12, 4, 14.
#
# Solution:
#
# Step-1 Sort data
# 1, 2, 4, 5, 10, 12, 14, 15
#
# Step-2 Find min, max, median, quartile values.
# Minimum value = 1
#
# Maximum value = 15
#
# Median = ((n + 1)/2)th term
#
# Here n = 8
#
# = ((8 + 1)/2)th term
#
# = (9/2)th term
#
# = 4.5th term
#
# 4.5th term is the average value of 4th and 5th term values
#
# Median = (5 + 10)/2
#
# =15/2 = 7.5
#
# Median = 7.5
#
# Quartile-1 = ((n + 1)/4)th term
#
# = ((8 + 1)/4)th term
#
# = (9/4)th term
#
# = 2.25th term
#
# 2.25th term is the average value of 2nd and 3rd term values
#
# Quartile-1 = (2 + 4)/2
#
# = 6/2 = 3
#
# Quartile-1 = 3
#
# Quartile-3 = (3(n + 1)/4)th term
#
# = (3(8 + 1)/4)th term
#
# = (3(9)/4)th term
#
# = (27/4)th term
#
#   = 6.75th term
#
# 6.75th term is the average value of 6th and 7th term values
#
# Quartile-3 = (12 + 14)/2
#
# = 26/2 = 13
#
# Quartile-3 = 13
